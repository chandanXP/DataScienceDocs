# %% [markdown]
# <a href="https://colab.research.google.com/github/chandanXP/DataScienceDocs/blob/main/Python_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Python Programming

# %% [markdown]
# ### Memory , variables

# %%
# ipynb  - IPython notebook
a=10  # implicitly
print(a)
# Out:
# 10

# %%
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-939330b76721> in <cell line: 1>()
# ----> 1 print(A)
#
# NameError: name 'A' is not defined

# %%
a=10
print( a, type(a), id(a))
# Out:
# 10 <class 'int'> 136221341811216

# %%
a=10.55
print( a, type(a), id(a))
# Out:
# 10.55 <class 'float'> 136220917479344

# %%
a="10"
print( a, type(a), id(a))
# Out:
# 10 <class 'str'> 136221334419248

# %%
x=10;y=20;
print(x,y)
z\
=\
30
print(z)
# Out:
# 10 20
# 30

# %%
a=10
print( "a  :",a," address(a) : ",  id(a))
b=10
print( "b  :",b," address(b) : ",  id(b))
c=a
print( "c  :",c," address(c) : ",  id(c))
# Out:
# a  : 10  address(a) :  136221341811216
# b  : 10  address(b) :  136221341811216
# c  : 10  address(c) :  136221341811216

# %%
a=11
print( "a  :",a," address(a) : ",  id(a))
print( "b  :",b," address(b) : ",  id(b))
print( "c  :",c," address(c) : ",  id(c))
# Out:
# a  : 11  address(a) :  136221341811248
# b  : 10  address(b) :  136221341811216
# c  : 10  address(c) :  136221341811216

# %%
a=10
print( "a  :",a," address(a) : ",  id(a))
print( "b  :",b," address(b) : ",  id(b))
print( "c  :",c," address(c) : ",  id(c))
# Out:
# a  : 10  address(a) :  136221341811216
# b  : 10  address(b) :  136221341811216
# c  : 10  address(c) :  136221341811216

# %%
d=11
print( "a  :",a," address(a) : ",  id(a))
print( "b  :",b," address(b) : ",  id(b))
print( "c  :",c," address(c) : ",  id(c))
print( "d  :",d," address(d) : ",  id(d))
# Out:
# a  : 10  address(a) :  136221341811216
# b  : 10  address(b) :  136221341811216
# c  : 10  address(c) :  136221341811216
# d  : 11  address(d) :  136221341811248

# %% [markdown]
# ### conditional statements , Loops

# %%
a=10
if a<5 :
  print("less")
  print("another line")
  print("sdf")
else:
  print("great")
# Out:
# great

# %%
a>5
# Out:
# True

# %%
a=0
while a<5 :
  print(a)
  a=a+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
x = range(5)
print(type(x))
# Out:
# <class 'range'>

# %%
for i in x:
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,5):
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
# range(stop) -> range object
# range(start, stop[, step]) -> range object
for i in range(20,30,2):
  print (i)
# Out:
# 20
# 22
# 24
# 26
# 28

# %%
for i in range(200,160,-5):
  print (i)
# Out:
# 200
# 195
# 190
# 185
# 180
# 175
# 170
# 165

# %%
l1 = [10,20,30,40]
for a in l1:
  print(a)
# Out:
# 10
# 20
# 30
# 40

# %%
a1 = 23+3j
a2 = -3-1j
print(a1,a2 , a1+a2)
# Out:
# (23+3j) (-3-1j) (20+2j)

# %%
a="india"
cnt = input("enter country")
if cnt == a :
  print("its india")
else :
  print(" not india")
# Out:
# enter countrypass
#  not india

# %% [markdown]
# #### String

# %%
cntry = "India"
print(cntry , type(cntry))
# Out:
# India <class 'str'>

# %%
print (cntry[0] , cntry[-1], cntry[-2])
# Out:
# I a i

# %%
print( cntry [1:3] , cntry[:3], cntry [2:] , cntry *2 )
# Out:
# nd Ind dia IndiaIndia

# %%
print ( cntry + " is great " ,end= " * " )
print (cntry *3)
# Out:
# India is great  * IndiaIndiaIndia

# %%
for i in cntry :
  print(i)
# Out:
# I
# n
# d
# i
# a

# %%
cntry.upper()
# Out:
# 'INDIA'

# %% [markdown]
# ### function

# %%
def showme():
  print ("i am show me funtion ")

# %%
showme()
# Out:
# i am show me funtion

# %%
def addme(a,b):
  ''' method add two (a, b ) number and return '''
  print ("i am add method ")
  return a+b

# %%
addme(10,20)
# Out:
# i am add method
# 30

# %%
addme.__doc__
# Out:
# ' method add two (a, b ) number and return '

# %%
def varfun( a1, *var):
  print("a1:", a1)
  for i in var:
    print(i)

# %%
varfun(10)
# Out:
# a1: 10

# %%
varfun(10,23,"45",56.34,67)
# Out:
# a1: 10
# 23
# 45
# 56.34
# 67

# %%
def allvarfun( *var):
  for i in var:
    print(i)

# %%
allvarfun()

# %%
allvarfun("india",34)
# Out:
# india
# 34
